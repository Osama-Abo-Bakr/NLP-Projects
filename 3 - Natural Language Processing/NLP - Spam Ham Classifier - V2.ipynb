# %% [markdown]
# # Main Library

# %%
# Reading Data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Make Preprocessing
from nltk.corpus import stopwords
import string
from nltk.tokenize import word_tokenize
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

# Build Model
import tensorflow as tf
import tensorflow.keras as k
from keras.layers import Embedding, Dense, GlobalAveragePooling1D

# Download Models
import pickle

# %% [markdown]
# # Reading Data

# %%
data = pd.read_csv(r"D:\Courses language programming\5_Machine Learning\Dataset For Machine Learning\Spam_Mail\mail_data.csv")
data.head(5)
# Out:
#   Category                                            Message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Category  5572 non-null   object
#  1   Message   5572 non-null   object
# dtypes: object(2)
# memory usage: 87.2+ KB

# %%
data.loc[data["Category"] == "spam", "Category"] = 1
data.loc[data["Category"] == "ham", "Category"] = 0

# %%
data.head(5)
# Out:
#   Category                                            Message
# 0        0  Go until jurong point, crazy.. Available only ...
# 1        0                      Ok lar... Joking wif u oni...
# 2        1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3        0  U dun say so early hor... U c already then say...
# 4        0  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# # Preprocessing

# %%
X = data["Message"]
stop_words = stopwords.words("english")

# %%
new_x = []
for sentence in X:
    new_word = ""
    for word in word_tokenize(sentence):
        if word.lower() not in set(stop_words) and word.lower() not in list(string.punctuation): 
            new_word += word
            new_word += " "
    new_x.append(new_word)    
new_x = np.array(new_x)

# %%
new_x
# Out:
# array(['Go jurong point crazy .. Available bugis n great world la e buffet ... Cine got amore wat ... ',
#        'Ok lar ... Joking wif u oni ... ',
#        "Free entry 2 wkly comp win FA Cup final tkts 21st May 2005 Text FA 87121 receive entry question std txt rate C 's apply 08452810075over18 's ",
#        ..., 'Pity mood ... suggestions ',
#        "guy bitching acted like 'd interested buying something else next week gave us free ",
#        'Rofl true name '], dtype='<U535')

# %% [markdown]
# # Splitting & Tokenization

# %%
# X = data["Message"]
Y = data["Category"].astype("int32")

# %%
label = to_categorical(Y, 2)

# %%
# Tokenization
# tokenize = Tokenizer(num_words=116,oov_token="<OOV>")
tokenize = Tokenizer(oov_token="<OOV>")
tokenize.fit_on_texts(new_x)
word_index = tokenize.word_index

data_sequance = tokenize.texts_to_sequences(new_x)

# Padding_Sequances
data_padding = pad_sequences(data_sequance, maxlen=116, padding="pre", truncating="pre")

# %%
input_length = max(len(seq) for seq in data_sequance)

vocabulary_size = len(word_index) + 1

# %%
data_padding
# Out:
# array([[   0,    0,    0, ...,   17, 4295,   73],
#        [   0,    0,    0, ...,  369,    2, 1813],
#        [   0,    0,    0, ...,  299, 2861,    5],
#        ...,
#        [   0,    0,    0, ..., 8773, 1207, 8774],
#        [   0,    0,    0, ...,  919,  128,   14],
#        [   0,    0,    0, ..., 2546,  367,  184]])

# %%
input_length, vocabulary_size
# Out:
# (97, 8776)

# %%
x_train, x_test, y_train, y_test = train_test_split(data_padding, label, train_size=0.7, random_state=42)

# %% [markdown]
# # Building Model ==> Neural Network

# %%
model = tf.keras.models.Sequential(
    [
        Embedding(vocabulary_size, 100, input_length=116),
        GlobalAveragePooling1D(),
        Dense(128, activation="relu"),
        Dense(24, activation="relu"),
        Dense(2, activation="softmax")
    ])
model.compile(optimizer="adam", loss=k.losses.CategoricalCrossentropy(), metrics=["accuracy", "mse"])

# %%
history = model.fit(x_train, y_train, epochs=30, validation_data=(x_test, y_test), verbose=2)
# Out:
# Epoch 1/30
# 122/122 - 3s - loss: 0.4238 - accuracy: 0.8608 - mse: 0.1320 - val_loss: 0.3550 - val_accuracy: 0.8660 - val_mse: 0.1077 - 3s/epoch - 24ms/step
# Epoch 2/30
# 122/122 - 1s - loss: 0.2978 - accuracy: 0.8695 - mse: 0.0898 - val_loss: 0.2087 - val_accuracy: 0.8840 - val_mse: 0.0666 - 522ms/epoch - 4ms/step
# Epoch 3/30
# 122/122 - 1s - loss: 0.0827 - accuracy: 0.9733 - mse: 0.0208 - val_loss: 0.0542 - val_accuracy: 0.9862 - val_mse: 0.0121 - 501ms/epoch - 4ms/step
# Epoch 4/30
# 122/122 - 1s - loss: 0.0309 - accuracy: 0.9915 - mse: 0.0072 - val_loss: 0.0479 - val_accuracy: 0.9868 - val_mse: 0.0112 - 523ms/epoch - 4ms/step
# Epoch 5/30
# 122/122 - 1s - loss: 0.0169 - accuracy: 0.9956 - mse: 0.0038 - val_loss: 0.0489 - val_accuracy: 0.9874 - val_mse: 0.0111 - 511ms/epoch - 4ms/step
# Epoch 6/30
# 122/122 - 0s - loss: 0.0120 - accuracy: 0.9967 - mse: 0.0026 - val_loss: 0.0629 - val_accuracy: 0.9839 - val_mse: 0.0131 - 494ms/epoch - 4ms/step
# Epoch 7/30
# 122/122 - 1s - loss: 0.0112 - accuracy: 0.9967 - mse: 0.0026 - val_loss: 0.0503 - val_accuracy: 0.9886 - val_mse: 0.0104 - 507ms/epoch - 4ms/step
# Epoch 8/30
# 122/122 - 1s - loss: 0.0070 - accuracy: 0.9982 - mse: 0.0015 - val_loss: 0.0461 - val_accuracy: 0.9886 - val_mse: 0.0098 - 524ms/epoch - 4ms/step
# Epoch 9/30
# 122/122 - 1s - loss: 0.0043 - accuracy: 0.9992 - mse: 7.9916e-04 - val_loss: 0.0464 - val_accuracy: 0.9886 - val_mse: 0.0095 - 519ms/epoch - 4ms/step
# Epoch 10/30
# 122/122 - 1s - loss: 0.0060 - accuracy: 0.9979 - mse: 0.0014 - val_loss: 0.0694 - val_accuracy: 0.9850 - val_mse: 0.0127 - 517ms/epoch - 4ms/step
# Epoch 11/30
# 122/122 - 1s - loss: 0.0036 - accuracy: 0.9995 - mse: 6.5478e-04 - val_loss: 0.0583 - val_accuracy: 0.9874 - val_mse: 0.0106 - 504ms/epoch - 4ms/step
# Epoch 12/30
# 122/122 - 1s - loss: 0.0035 - accuracy: 0.9995 - mse: 6.4110e-04 - val_loss: 0.0618 - val_accuracy: 0.9868 - val_mse: 0.0111 - 507ms/epoch - 4ms/step
# Epoch 13/30
# 122/122 - 1s - loss: 0.0024 - accuracy: 0.9992 - mse: 5.4990e-04 - val_loss: 0.0614 - val_accuracy: 0.9874 - val_mse: 0.0108 - 514ms/epoch - 4ms/step
# Epoch 14/30
# 122/122 - 1s - loss: 0.0021 - accuracy: 0.9995 - mse: 4.7832e-04 - val_loss: 0.0525 - val_accuracy: 0.9904 - val_mse: 0.0089 - 511ms/epoch - 4ms/step
# Epoch 15/30
# 122/122 - 1s - loss: 0.0038 - accuracy: 0.9985 - mse: 0.0011 - val_loss: 0.0606 - val_accuracy: 0.9886 - val_mse: 0.0105 - 510ms/epoch - 4ms/step
# Epoch 16/30
# 122/122 - 1s - loss: 0.0030 - accuracy: 0.9990 - mse: 6.8249e-04 - val_loss: 0.0814 - val_accuracy: 0.9850 - val_mse: 0.0134 - 504ms/epoch - 4ms/step
# Epoch 17/30
# 122/122 - 1s - loss: 0.0031 - accuracy: 0.9995 - mse: 7.0376e-04 - val_loss: 0.0828 - val_accuracy: 0.9850 - val_mse: 0.0134 - 508ms/epoch - 4ms/step
# Epoch 18/30
# 122/122 - 1s - loss: 0.0020 - accuracy: 0.9995 - mse: 4.5975e-04 - val_loss: 0.0728 - val_accuracy: 0.9862 - val_mse: 0.0119 - 520ms/epoch - 4ms/step
# Epoch 19/30
# 122/122 - 1s - loss: 7.9759e-04 - accuracy: 0.9995 - mse: 1.9566e-04 - val_loss: 0.0741 - val_accuracy: 0.9862 - val_mse: 0.0120 - 504ms/epoch - 4ms/step
# Epoch 20/30
# 122/122 - 1s - loss: 0.0018 - accuracy: 0.9995 - mse: 4.3467e-04 - val_loss: 0.0532 - val_accuracy: 0.9916 - val_mse: 0.0077 - 510ms/epoch - 4ms/step
# Epoch 21/30
# 122/122 - 1s - loss: 0.0019 - accuracy: 0.9995 - mse: 5.1902e-04 - val_loss: 0.0549 - val_accuracy: 0.9892 - val_mse: 0.0089 - 529ms/epoch - 4ms/step
# Epoch 22/30
# 122/122 - 1s - loss: 0.0013 - accuracy: 0.9995 - mse: 3.2656e-04 - val_loss: 0.0612 - val_accuracy: 0.9892 - val_mse: 0.0094 - 507ms/epoch - 4ms/step
# Epoch 23/30
# 122/122 - 1s - loss: 0.0010 - accuracy: 0.9997 - mse: 2.6274e-04 - val_loss: 0.1653 - val_accuracy: 0.9372 - val_mse: 0.0446 - 513ms/epoch - 4ms/step
# Epoch 24/30
# 122/122 - 1s - loss: 0.0038 - accuracy: 0.9987 - mse: 9.6624e-04 - val_loss: 0.0602 - val_accuracy: 0.9868 - val_mse: 0.0106 - 532ms/epoch - 4ms/step
# Epoch 25/30
# 122/122 - 1s - loss: 0.0014 - accuracy: 0.9995 - mse: 3.7169e-04 - val_loss: 0.0788 - val_accuracy: 0.9862 - val_mse: 0.0125 - 516ms/epoch - 4ms/step
# Epoch 26/30
# 122/122 - 1s - loss: 8.7018e-04 - accuracy: 0.9997 - mse: 2.3031e-04 - val_loss: 0.0623 - val_accuracy: 0.9880 - val_mse: 0.0092 - 519ms/epoch - 4ms/step
# Epoch 27/30
# 122/122 - 1s - loss: 0.0023 - accuracy: 0.9992 - mse: 6.6895e-04 - val_loss: 0.0665 - val_accuracy: 0.9850 - val_mse: 0.0124 - 520ms/epoch - 4ms/step
# Epoch 28/30
# 122/122 - 1s - loss: 5.8573e-04 - accuracy: 0.9997 - mse: 1.2698e-04 - val_loss: 0.0703 - val_accuracy: 0.9862 - val_mse: 0.0110 - 501ms/epoch - 4ms/step
# Epoch 29/30
# 122/122 - 1s - loss: 0.0053 - accuracy: 0.9985 - mse: 0.0015 - val_loss: 0.0876 - val_accuracy: 0.9862 - val_mse: 0.0130 - 506ms/epoch - 4ms/step
# Epoch 30/30
# 122/122 - 1s - loss: 0.0012 - accuracy: 0.9995 - mse: 3.3355e-04 - val_loss: 0.0657 - val_accuracy: 0.9886 - val_mse: 0.0096 - 509ms/epoch - 4ms/step

# %%
plt.plot(history.history["loss"], label="Loss")
plt.plot(history.history["val_loss"], label="Val_Loss")

plt.xlabel("Epochs")
plt.ylabel("Loss")

plt.title("Loss Vs Epochs")

plt.legend()
plt.grid()

# %%
plt.plot(history.history["mse"], label="mse")
plt.plot(history.history["val_mse"], label="val_mse")

plt.xlabel("Epochs")
plt.ylabel("Accuracy")

plt.title("Accuracy Vs Epochs")

plt.legend()
plt.grid()

# %%
plt.plot(history.history["accuracy"], label="accuracy")
plt.plot(history.history["val_accuracy"], label="val_accuracy")

plt.xlabel("Epochs")
plt.ylabel("Accuracy")

plt.title("Accuracy Vs Epochs")

plt.legend()
plt.grid()

# %% [markdown]
# # Make System Prediction

# %%
text = input().split()

new_text = ""
for word in text:
    if word not in stop_words and word not in list(string.punctuation):
        new_text += word
        new_text += " "

test_sequace = tokenize.texts_to_sequences([new_text])
test_padding = pad_sequences(test_sequace, maxlen=116, padding="pre", truncating="pre")


# test_sequace
prediction = model.predict(test_padding)

if np.argmax(prediction) == 1: print("This Massage is -->  SPAM ")
else: print("This Massage is -->  HAM ")
# Out:
# SIX chances to win CASH! From 100 to 20,000 pounds txt> CSH11 and send to 87575. Cost 150p/day, 6days, 16+ TsandCs apply Reply HL 4 info
# 1/1 [==============================] - 0s 65ms/step
# This Massage is -->  SPAM

# %%
SIX chances to win CASH! From 100 to 20,000 pounds txt> CSH11 and send to 87575. Cost 150p/day, 6days, 16+ TsandCs apply Reply HL 4 info

# %% [markdown]
# # Downloading Models In Device

# %%
pickle.dump(model, open(r"D:\Pycharm\model_pickle\NLP - Models\Spam_Ham-Emails.bin", "wb"))
# Out:
# INFO:tensorflow:Assets written to: ram://c3595f9e-8e32-46ed-9500-da49373ad61c/assets
